# %%
from ObjectivelyFunny.data import get_data
# Out:
# 2022-03-10 11:46:32.795148: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-10 11:46:32.795212: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
df = get_data()

# %%
df['artist'].nunique()
# Out:
# 268

# %% [markdown]
# # Le Wagon Data Science Batch 805 : Objectively Funny

# %% [markdown]
# # Objectively Funny
# ### Adventures in Comedy AI
# Yuqing Wang, Catriona Beamish,
# James Farrell, Reinis Melbardis
#
# 11/03/2022, London, UK

# %% [markdown]
# <center><img src="https://miro.medium.com/max/750/1*MzKEdDDJhdrmRP6ssOuleQ.jpeg"
#      alt = "C3PO being a jokester"
#      width="250"
#      height="250" /></center>

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# 😃 Comedy is nuanced and a highly "human" thing.
#
# 📚 Can we gain insight into how humour is created through natural language processing?
#
# 🧠 Can artificial brains be funny?

# %% [markdown]
# ## 📜 Data
# [Scraps From the Loft - Full Scripts of Stand-up specials](http://scrapsfromtheloft.com/stand-up-comedy-scripts/) - scripts and year
# <img src="https://i.ibb.co/dQThQ99/Capture.png"
#      alt = "Diagrams"
#      width="700"
#      height="250" />
#
# [Subsaga - Live from the BBC, Live at the Apollo and Full Scripts](https://subsaga.com/bbc/browse/genre/comedy/standup/?page=0) - scripts
# <img src="https://i.ibb.co/ry19Gwb/Capture-2.png"
#      alt = "Diagrams"
#      width="700"
#      height="250" />
#
#
# [The Movie Database (TMDB)](https://www.themoviedb.org/?language=en-GB) - artist age and gender

# %% [markdown]
# <img src="https://i.ibb.co/FhsMXqQ/Screenshot-2022-03-10-at-16-50-02.png"
#      alt = "Data Information"
#      width="700"
#      height="700" />

# %% [markdown]
# <img src="https://raw.githubusercontent.com/rmelbardis/ObjectivelyFunny/master/images/diagrams.png"
#      alt = "Diagrams"
#      width="800"
#      height="800" />

# %% [markdown]
# ## Project Outcomes

# %% [markdown]
# 🎯 We focussed on two goals:
# - Analysis of common topics and words in stand-up comedy
# - Training an AI to write stand-up, with hilarious consequences

# %% [markdown]
# ![workflow-2-paths.001.jpeg](attachment:workflow-2-paths.001.jpeg)

# %% [markdown]
# Before and after preprocessing
#
# ![gif-transform.gif](attachment:gif-transform.gif)

# %% [markdown]
# ### 💭 Demo time - Look at our topics! 💭

# %% [markdown]
# ### 🤖 Create a Comedy Bot using Deep Learning

# %% [markdown]
# - OpenAI's Generative Pre-trained Transformer 2 (GPT-2).
#     - Credit for tools: [Max Woolf](https://github.com/minimaxir/gpt-2-simple)
#
# - Female comedian dataset
#
# - Big model - deployed to cloud platform

# %%
df['artist'][df['artist_gender']==1].unique()
# Out:
# array(['Aisling Bea', 'Ali Wong', 'Amanda Seales', 'Amy Schumer',
#        'Andi Osho', 'Angela Barnes', 'Anjelah Johnson', 'Bridget Everett',
#        'Celia Pacquola', 'Chelsea Peretti', 'Christina Pazsitzky',
#        'Cristela Alonzo', 'Dawn French', 'Desiree Burch',
#        'Ellen Degeneres', 'Ellie Taylor', 'Emily Heller', 'Enissa Amani',
#        'Felicity Ward', 'Francesca Martinez', 'Gina Yashere',
#        'Hannah Gadsby', 'Holly Walsh', 'Iliza Shlesinger', 'Jen Brister',
#        'Jen Kirkman', 'Katherine Ryan', 'Kathleen Madigan',
#        'Kerry Godliman', 'Lisa Lampanelli', 'Lucy Porter',
#        'Luisa Omielan', 'Maria Bamford', 'Michelle Wolf', 'Miranda Hart',
#        'Nikki Glaser', 'Roisin Conaty', 'Sara Pascoe', 'Sarah Cooper',
#        'Sarah Millican', 'Sarah Silverman', 'Shappi Khorsandi',
#        'Tiffany Haddish', 'Tig Notaro', 'Urzila Carlson', 'Victoria Wood',
#        'Wanda Sykes', 'Whitney Cummings', 'Zoe Lyons'], dtype=object)

# %% [markdown]
# ### Ladies and Gentlemen, please welcome to the stage...  Robecca Stepford!
#
# <center><img src="https://raw.githubusercontent.com/rmelbardis/ObjectivelyFunny/master/app/images/robecca.png"
#      alt = "Robecca"
#      width="500"
#      height="500" /></center>

# %% [markdown]
# ### 🚀 Future Work

# %% [markdown]
# - Open-source our dataset for public use
#
# - Bigger & more modern text generation models for transfer learning
#
# - Train model from scratch ourselves

# %% [markdown]
# ## ❓ Q&A ❓

# %% [markdown]
# # Thank you for listening to us, you've been a wonderful audience!
# ## We've been Objectively Funny, have a great night!
#
# <center><img src="https://raw.githubusercontent.com/rmelbardis/ObjectivelyFunny/master/app/images/logo.png"
#      alt = "Robot"
#      width="300"
#      height="300" /></center>
