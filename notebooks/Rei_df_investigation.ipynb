# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from ObjectivelyFunny.data import get_data
# Out:
# 2022-03-08 10:52:51.276020: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-08 10:52:51.276072: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
df = get_data(gender=[1])

# %%
clean_df = df.copy()

# %%
clean_df
# Out:
#                                       full_transcript            artist  \
# 0   ! APPLAUSE AND CHEERING Hello! Hello, The Apol...       Aisling Bea
# 1   Ladies and gentlemen, please welcome to the st...          Ali Wong
# 2   Ladies and gentlemen, please welcome to the st...          Ali Wong
# 3   Now, y’all keep asking me, “Amanda, who is thi...     Amanda Seales
# 4   My name is Amy, and it’s my show! ♪ Man ♪ ♪ Uh...       Amy Schumer
# ..                                                ...               ...
# 77  Ladies and gentlemen… !\n\nYes. Yes. Thank you...       Wanda Sykes
# 78  (techno music playing) ♪ ♪ ♪ Play it, say it, ...  Whitney Cummings
# 79  Ladies and gentlemen, from the Barclay Theatre...  Whitney Cummings
# 80  Ladies and gentlemen… !\n\nThis is awesome. I ...  Whitney Cummings
# 81  , ladies and gentlemen! CHEERING AND APPLAUSE ...         Zoe Lyons
#
#                                  show_name    year                source  \
# ...
