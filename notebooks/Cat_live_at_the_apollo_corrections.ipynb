# %%
import pandas as pd

# %%
df = pd.read_json('../raw_data/live_at_the_apollo_doubles_removed.json')

# %%
df
# Out:
#                                                   url  \
# 0   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 1   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 2   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 3   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 4   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 5   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 6   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 7   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 8   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 9   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 10  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 11  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 12  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 13  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 14  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 15  https://subsaga.com/bbc/comedy/live-at-the-apo...
# ...

# %%
df['host_script'] = df['full_transcript']
#[x.split(df['Comedian1'].string)[-0] for x in df['full_transcript']]
df['com1_script'] = df['full_transcript']
#[x.split(df['Comedian1'].string)[-1] for x in df['full_transcript']]
df['com2_script'] = df['full_transcript']
#[x.split(df['Comedian2'].string)[-1] for x in df['full_transcript']]

# %%
for i,row in df.iterrows():
    df['host_script'][i]= df['full_transcript'][i].split(str(df['Comedian1'][i]))[-0]
# Out:
# /var/folders/wx/fdznh_y51_1gnn8tvkcxhsyh0000gn/T/ipykernel_11980/2013577573.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_script'][i]= df['full_transcript'][i].split(str(df['Comedian1'][i]))[-0]

# %%
df['Comedian1'][21] = 'Lucy Porter'
df['Comedian1'][22] = 'Desiree Burch'
df['Comedian1'][23] = 'Angela Barnes'
df['Comedian1'][36] = 'John Richardson'
df['Comedian1'][2] = 'Aisling Bea'
df['Comedian2'][2] = 'Simon Evans'
df['Comedian2'][21] = 'Guz Khan'
df['Comedian2'][22] = 'Chris McCausland'
df['Comedian2'][23] = 'Geoff Norcott'
df['Comedian1'][31] = 'Reginald D Hunter'
df['Comedian2'][31] = 'Kevin Bridges'
df['Comedian1'][50] = 'Julian Clary'
df['Comedian2'][50] = 'Reginald D Hunter'
# Out:
# /var/folders/wx/fdznh_y51_1gnn8tvkcxhsyh0000gn/T/ipykernel_11980/1970323832.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Comedian1'][21] = 'Lucy Porter'
# /var/folders/wx/fdznh_y51_1gnn8tvkcxhsyh0000gn/T/ipykernel_11980/1970323832.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Comedian1'][22] = 'Desiree Burch'
# /var/folders/wx/fdznh_y51_1gnn8tvkcxhsyh0000gn/T/ipykernel_11980/1970323832.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['host_script'][2]
# Out:
# ' Ladies and gentlemen, please welcome your host for tonight, Frankie Boyle! CHEERING Hello! AUDIENCE: Hello! Hello and welcome to Live At The Apollo. I\'m quite surprised that they\'ve let me on as well, if that\'s any comfort. HE LAUGHS I\'ve got a lovely theatre, I\'ve got two fantastic comedians to introduce to you tonight, I\'ve got a lovely audience to talk to... I looked right into your eyes when I said that, mate. How you doing? You have made an effort there, haven\'t you, man? You have made an effort with the Peaky Blinders hairstyle there. And it\'s like putting 26-inch rims on a wheelie bin. We\'ve got some famous celebrities to talk to tonight. And some not-so famous. Some of the celebrities here tonight, when I was researching the show, I had to start their Wikipedia page. There are celebrities in here who don\'t get asked to turn on the Christmas lights in their own house. You\'re talking about people who are 18 months away from being quite a tricky tie-breaker in a pub
# ...

# %%
df['com1_script'] = df.apply(lambda row: row['full_transcript'].replace(str(row['host_script']),''),axis=1)
df['com2_script'] = df.apply(lambda row: row['full_transcript'].replace(str(row['host_script']),''),axis=1)

# %%
print(df['full_transcript'][36])
# Out:
#  CHEERING AND APPLAUSE Good evening, ladies and gentlemen, and welcome to Live At The Apollo! Oh, yes, were going to have a good time tonight. Thank you very much for coming out. Looking around the audience, who do we have in this evening? Mr Colin Jackson. In the house! Yeah, Olympic and world superstar. Hurdler, yeah? But I notice also, a slightly high voice. Is that one of the hazards of hurdling? Welcome, Colin. Nice to have you here. Oh, the lovely Esther Rantzen is here. -Hello, Miss Esther, how are you? -I'm good, thanks. -Very nice to have you here. Unfortunately, if you don't like this show there is not any complaining procedure. Sorry, but that's...life. Welcome, welcome. Before we start, I want to tell you a little bit about myself. I come from quite a big family. There are eight kids in the family. Now, what can I tell you about that? Well, my dad loved the Jackson Five. And, quite clearly, sex. Very, very tough existence. I remember as a young kid saying to my dad, "Dad,
# ...

# %%
df[['Comedian1','com1_script']]
# Out:
#              Comedian1                                        com1_script
# 0           Joe Lycett  Joe Lycett! CHEERING Wow! Lovely. Hello. CHEER...
# 1         Chris Ramsey  Chris Ramsey!  CHEERING  Yes!  Hello!  How you...
# 2          Aisling Bea  Aisling Bea! APPLAUSE AND CHEERING Hello! Hell...
# 3          Sara Pascoe  Sara Pascoe! CHEERING AND APPLAUSE CHEERING He...
# 4     Justin Moorhouse  Justin Moorhouse. CHEERING Hello. Wow! Look at...
# 5           Miles Jupp  Miles Jupp! Hello! Oh, Hammersmith, how very d...
# 6   Francesca Martinez  Francesca Martinez! APPLAUSE AND CHEERING CHEE...
# 7            Zoe Lyons  Zoe Lyons, ladies and gentlemen! CHEERING AND ...
# 8        Dane Baptiste  Dane Baptiste. CHEERING AND APPLAUSE Thank you...
# 9          Jason Byrne  Jason Byrne! CHEERING Hello! OK, so I was Aust...
# 10        Henning Wehn  Henning Wehn. CHEERING AND APPLAUSE \nMUSIC: 9...
# 11       Roisin Conaty  Roisin Conaty! CHEERING Hello! Hello! Hello! Y...
# ...

# %%
for i,row in df.iterrows():
    df['com1_script'][i]= df['com1_script'][i].split(str(df['Comedian2'][i]))[-0]
# Out:
# /var/folders/wx/fdznh_y51_1gnn8tvkcxhsyh0000gn/T/ipykernel_11980/2982460812.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['com1_script'][i]= df['com1_script'][i].split(str(df['Comedian2'][i]))[-0]

# %%
df['com2_script'] = df.apply(lambda row: row['com2_script'].replace(str(row['com1_script']),''),axis=1)

# %%
print(df['full_transcript'][50])
# Out:
#  Ladies and gentlemen, please welcome your host for tonight, Omid Djalili.  Good evening! Are you well?  You all had a drink?  You all up for a laugh?  And THAT is why the West must be destroyed!  You know, when I travel round the world doing  stand-up comedy, I love languages. And you can pick up  languages by talking to people, just by talking to people.  Which is why I know the words, "Get off, you're crap!"  in 12 languages, actually.  SPEAKS UZBEK  Yeah, like the Uzbeks know anything about comedy!  But sometimes, speaking a different language is actually quite helpful.  Like, for example, I love Italian food, but I hate it  when they leave the shells on the prawns.  But if you speak to the Italian waiter in his own language,  he can sort it out. I'll say, "Si, come stai?  "Allora. Per favore, e possibile, i gamberoni...  "Can you take the shells off?"  Haven't quite mastered it yet.  It also works in Arabic shops as well.  I'll go up to an Arab, I'll say,  "Habibi..."  SPEAKS FA
# ...

# %%
df[['Comedian2','com2_script']]
# Out:
#             Comedian2                                        com2_script
# 0        Russell Kane  Russell Kane. Hello. How are you doing, Apollo...
# 1           Doc Brown  Doc Brown!  APPLAUSE  Yeah!  Yeah, yeah, yeah....
# 2         Simon Evans  Simon Evans! CHEERING Thank you. Thank you ver...
# 3        Nathan Caton  Nathan Caton! CHEERING AND APPLAUSE Hello, hel...
# 4           Tom Stade  Tom Stade! APPLAUSE All right... Well, good ev...
# 5          Lee Nelson  Lee Nelson! Good Evening, Apollo. Yes! Oh, peo...
# 6          Nish Kumar  Nish Kumar! CHEERING AND APPLAUSE Good evening...
# 7       Paul Chowdhry  Paul Chowdhry, ladies and gentlemen. CHEERING ...
# 8           Al Porter  Al Porter. CHEERING AND APPLAUSE Hello. Are yo...
# 9     Stewart Francis  Stewart Francis! CHEERING Thank you, thank you...
# 10      James Acaster  James Acaster. CHEERING AND APPLAUSE \nMUSIC P...
# 11          Nick Helm  Nick Helm! CHEERING Good evening, Live At The ...
# ...

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 1  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 2  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 3  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 4  https://subsaga.com/bbc/comedy/live-at-the-apo...
#
#                                     title  \
# 0  Live at the Apollo Series 10 Episode 1
# 1  Live at the Apollo Series 10 Episode 2
# 2  Live at the Apollo Series 10 Episode 3
# 3  Live at the Apollo Series 10 Episode 4
# 4  Live at the Apollo Series 10 Episode 5
#
#                                      full_transcript  series  episode   wiki  \
# 0   Ladies and gentlemen, please welcome your hos...      10        1  10x01
# 1   Ladies and gentlemen, please welcome  your ho...      10        2  10x02
# 2   Ladies and gentlemen, please welcome your hos...      10        3  10x03
# ...

# %%
df['patter'] = df['com1_script']
for i,row in df.iterrows():
    df['patter'][i]= df['com1_script'][i].split(str(df['Comedian1'][i]))[-1]
# Out:
# /var/folders/wx/fdznh_y51_1gnn8tvkcxhsyh0000gn/T/ipykernel_11980/1557747543.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['patter'][i]= df['com1_script'][i].split(str(df['Comedian1'][i]))[-1]

# %%
df['patter']
# Out:
# 0     ! Your next act is a great comic and a lovely ...
# 1     ! Oh, wow!  Are you ready for your next act?  ...
# 2     . Have a fantastic evening! Give it up for Ais...
# 3     ! CHEERING Are you ready for our final act of ...
# 4     , ladies and gentlemen! Ladies and gentlemen, ...
# 5     , everyone! OK, ladies and gentlemen, are you ...
# 6     ! Fantastic. Absolutely brilliant. I think we ...
# 7     ! CHEERING Let's keep that going as I bring on...
# 8     , ladies and gentlemen. CHEERING AND APPLAUSE ...
# 9     , ladies and gentlemen. Ladies and gentlemen, ...
# 10    . Well done. My next guest is absolutely incre...
# 11    , ladies and gentlemen! Ladies and gentlemen, ...
# 12    ! CHEERING Are you ready for your next act? CH...
# 13    ! Now, are we ready for our next act? CHEERING...
# 14    ! WHOOPING I ain't got any kids. Kids scare me...
# 15    ?! CHEERING AND APPLAUSE Ladies and gentlemen,...
# 16    , ladies and gentlemen! Are you ready for your...
# ...

# %%
df['com1_script'] = df.apply(lambda row: row['com1_script'].replace(str(row['patter']),''),axis=1)

# %%
df['patter'] = df['com2_script']
for i,row in df.iterrows():
    df['patter'][i]= df['com2_script'][i].split(str(df['Comedian2'][i]))[-1]
# Out:
# /var/folders/wx/fdznh_y51_1gnn8tvkcxhsyh0000gn/T/ipykernel_11980/4270040779.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['patter'][i]= df['com2_script'][i].split(str(df['Comedian2'][i]))[-1]

# %%
df['com2_script'] = df.apply(lambda row: row['com2_script'].replace(str(row['patter']),''),axis=1)

# %%
df['com2_script'][0]
# Out:
# 'Russell Kane. Hello. How are you doing, Apollo? Can\'t believe I am back again. Sarah Millican, ladies and gentlemen, don\'t you love her? This show is watched the world over, so it\'s great for trying to explain British humour. British people give me cheer... CHEERING Most of us. Who\'s not from the United Kingdom and Ireland, give me a cheer. CHEERING -Where are you from?-Australia. -Someone from Australia! QUIET CHEERING Now, I\'m sorry, I haven\'t even begun yet. You see that lacklustre response? -What\'s your name, mate?-Nathan. IMITATES: Nathan from Australia, ladies and gentlemen. That\'s everything you need to know about the British attitude to social mores, right there. I was on stage in New York recently, tiny little club and went, "Anyone from overseas?" There was someone from New Zealand. The rest of the room, they went, "Oh, my God, New Zealand, "you\'re most welcome, hooray." SINGSONG VOICE: "Welcome to our club, someone from overseas is in the room, "the energy is inc
# ...

# %%
df
# Out:
#                                                   url  \
# 0   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 1   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 2   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 3   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 4   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 5   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 6   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 7   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 8   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 9   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 10  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 11  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 12  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 13  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 14  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 15  https://subsaga.com/bbc/comedy/live-at-the-apo...
# ...

# %%
df['title'] = 'Live at the Apollo Series ' + df['series'].astype(str) + ' Episode ' + df['episode'].astype(str)

# %%
df
# Out:
#                                                   url  \
# 0   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 1   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 2   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 3   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 4   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 5   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 6   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 7   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 8   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 9   https://subsaga.com/bbc/comedy/live-at-the-apo...
# 10  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 11  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 12  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 13  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 14  https://subsaga.com/bbc/comedy/live-at-the-apo...
# 15  https://subsaga.com/bbc/comedy/live-at-the-apo...
# ...

# %%
final_df = df[['title', 'Host', 'Comedian1', 'Comedian2', 'Year', 'host_script', 'com1_script', 'com2_script' ]]

# %%
final_df
# Out:
#                                      title  \
# 0   Live at the Apollo Series 10 Episode 1
# 1   Live at the Apollo Series 10 Episode 2
# 2   Live at the Apollo Series 10 Episode 3
# 3   Live at the Apollo Series 10 Episode 4
# 4   Live at the Apollo Series 10 Episode 5
# 5   Live at the Apollo Series 10 Episode 6
# 6   Live at the Apollo Series 11 Episode 1
# 7   Live at the Apollo Series 11 Episode 2
# 8   Live at the Apollo Series 11 Episode 3
# 9   Live at the Apollo Series 11 Episode 4
# 10  Live at the Apollo Series 11 Episode 5
# 11  Live at the Apollo Series 11 Episode 6
# 12  Live at the Apollo Series 12 Episode 1
# 13  Live at the Apollo Series 12 Episode 2
# 14  Live at the Apollo Series 12 Episode 3
# 15  Live at the Apollo Series 12 Episode 4
# 16  Live at the Apollo Series 12 Episode 5
# 17  Live at the Apollo Series 12 Episode 6
# 18  Live at the Apollo Series 13 Episode 1
# 19  Live at the Apollo Series 13 Episode 2
# 20  Live at the Apollo Series 13 Episode 3
# ...

# %%
host_df = final_df[['title', 'host_script', 'Host', 'Year']]
com1_df = final_df[['title', 'com1_script', 'Comedian1', 'Year']]
com2_df = final_df[['title', 'com2_script', 'Comedian2', 'Year']]

# %%
host_df = host_df.rename(columns = {'host_script': 'full_transcript', 'Host': 'artist'})
com1_df = com1_df.rename(columns = {'com1_script': 'full_transcript', 'Comedian1': 'artist'})
com2_df = com2_df.rename(columns = {'com2_script': 'full_transcript', 'Comedian2': 'artist'})

# %%
full_df = pd.concat([host_df, com1_df, com2_df])

# %%
full_df = full_df.reset_index(drop=True)

# %%
full_df = full_df.drop(columns=['index'])

# %%
full_df = full_df.drop([85])

# %%
full_df.to_json('live_at_the_apollo.json')

# %%
full_df[['title','full_transcript', 'artist']][100:150]
# Out:
#                                       title  \
# 100   Live at the Apollo Series 8 Episode 1
# 101   Live at the Apollo Series 8 Episode 2
# 102   Live at the Apollo Series 8 Episode 3
# 103   Live at the Apollo Series 8 Episode 4
# 104   Live at the Apollo Series 8 Episode 5
# 105   Live at the Apollo Series 8 Episode 6
# 106   Live at the Apollo Series 9 Episode 1
# 107   Live at the Apollo Series 9 Episode 2
# 108   Live at the Apollo Series 9 Episode 3
# 109   Live at the Apollo Series 9 Episode 4
# 110   Live at the Apollo Series 9 Episode 5
# 111   Live at the Apollo Series 9 Episode 6
# 112  Live at the Apollo Series 10 Episode 1
# 113  Live at the Apollo Series 10 Episode 2
# 114  Live at the Apollo Series 10 Episode 3
# 115  Live at the Apollo Series 10 Episode 4
# 116  Live at the Apollo Series 10 Episode 5
# 117  Live at the Apollo Series 10 Episode 6
# 118  Live at the Apollo Series 11 Episode 1
# 119  Live at the Apollo Series 11 Episode 2
# ...
