# %%
import pandas as pd

# %%
pd.set_option("display.max_rows", None)

# %%
scraps_df = pd.read_json('../raw_data/scraps_clean.json')

# %%
apollo_df = pd.read_json('../raw_data/live_at_the_apollo_corrected.json')

# %%
live_bbc_df = pd.read_json('../raw_data/live_at_the_bbc_split.json')

# %%
bbc_scripts_df = pd.read_json('../raw_data/bbc_scripts_organised.json')

# %%
scraps_df.drop(columns='title', inplace=True)

# %%
scraps_df['artist'].iloc[105] = 'Tom Segura'
scraps_df['show_name'].iloc[105] = 'Overdoses – This Is Not Happening'
# Out:
# /tmp/ipykernel_10190/1499496762.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scraps_df['artist'].iloc[105] = 'Tom Segura'
# /tmp/ipykernel_10190/1499496762.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scraps_df['show_name'].iloc[105] = 'Overdoses – This Is Not Happening'

# %%
scraps_df.columns
# Out:
# Index(['full_transcript', 'artist', 'show_name', 'year'], dtype='object')

# %%
apollo_df
# Out:
#                                       title  \
# 0    Live at the Apollo Series 10 Episode 1
# 1    Live at the Apollo Series 10 Episode 2
# 2    Live at the Apollo Series 10 Episode 3
# 3    Live at the Apollo Series 10 Episode 4
# 4    Live at the Apollo Series 10 Episode 5
# 5    Live at the Apollo Series 10 Episode 6
# 6    Live at the Apollo Series 11 Episode 1
# 7    Live at the Apollo Series 11 Episode 2
# 8    Live at the Apollo Series 11 Episode 3
# 9    Live at the Apollo Series 11 Episode 4
# 10   Live at the Apollo Series 11 Episode 5
# 11   Live at the Apollo Series 11 Episode 6
# 12   Live at the Apollo Series 12 Episode 1
# 13   Live at the Apollo Series 12 Episode 2
# 14   Live at the Apollo Series 12 Episode 3
# 15   Live at the Apollo Series 12 Episode 4
# 16   Live at the Apollo Series 12 Episode 5
# 17   Live at the Apollo Series 12 Episode 6
# 18   Live at the Apollo Series 13 Episode 1
# 19   Live at the Apollo Series 13 Episode 2
# ...

# %%
apollo_df.columns = ['show_name', 'full_transcript', 'artist', 'year']

# %%
live_bbc_df
# Out:
#     index                                                url  \
# 0       0  https://subsaga.com/bbc/comedy/live-from-the-b...
# 1       1  https://subsaga.com/bbc/comedy/live-from-the-b...
# 2       2  https://subsaga.com/bbc/comedy/live-from-the-b...
# 3       3  https://subsaga.com/bbc/comedy/live-from-the-b...
# 4       4  https://subsaga.com/bbc/comedy/live-from-the-b...
# 5       5  https://subsaga.com/bbc/comedy/live-from-the-b...
# 6       0  https://subsaga.com/bbc/comedy/live-from-the-b...
# 7       1  https://subsaga.com/bbc/comedy/live-from-the-b...
# 8       2  https://subsaga.com/bbc/comedy/live-from-the-b...
# 9       3  https://subsaga.com/bbc/comedy/live-from-the-b...
# 10      4  https://subsaga.com/bbc/comedy/live-from-the-b...
# 11      5  https://subsaga.com/bbc/comedy/live-from-the-b...
#
#                  Show             Name  \
# 0   Live from the BBC        Adam Hess
# 1   Live from the BBC       Larry Dean
# 2   Live from the BBC   Kerry & Kurtan
# ...

# %%
live_bbc_df = live_bbc_df.drop([2, 8]).reset_index(drop=True)

# %%
live_bbc_df.drop(columns=['index', 'url'], inplace=True)

# %%
live_bbc_df['year'] = 2016.0

# %%
live_bbc_df.columns = ['show_name', 'artist', 'full_transcript', 'year']

# %%
live_bbc_df
# Out:
#            show_name          artist  \
# 0  Live from the BBC       Adam Hess
# 1  Live from the BBC      Larry Dean
# 2  Live from the BBC   Spencer Jones
# 3  Live from the BBC       Tez Ilyas
# 4  Live from the BBC      Mae Martin
# 5  Live from the BBC   Dane Baptiste
# 6  Live from the BBC   Felicity Ward
# 7  Live from the BBC   James Acaster
# 8  Live from the BBC    Alex Edelman
# 9  Live from the BBC      Nish Kumar
#
#                                      full_transcript    year
# 0    strong language. CHEERING Yes, yes, yes! How...  2016.0
# 1    some strong language CHEERING AND APPLAUSE L...  2016.0
# 2   CHEERING AND APPLAUSE CHEERING AND APPLAUSE #...  2016.0
# 3   CHEERING AND APPLAUSE Good evening, BBC. Are ...  2016.0
# 4     CHEERING AND APPLAUSE Hi! Hi, guys, how's i...  2016.0
# 5  Dane Baptiste. Thank you for coming to this re...  2016.0
# 6  Felicity Ward and it's very nice to be here. I...  2016.0
# ...

# %%
bbc_scripts_df.drop(columns=['index', 'url', 'title'], inplace=True)

# %%
bbc_scripts_df['source'] = 'BBC'
live_bbc_df['source'] = 'BBC'
apollo_df['source'] = 'BBC'
scraps_df['source'] = 'Scraps from the Loft'

# %%
bbc_scripts_df['year'] = 1000.0

# %%
bbc_scripts_df.columns = ['full_transcript', 'artist', 'show_name', 'source', 'year']

# %%
bbc_scripts_df
# Out:
#                                       full_transcript              artist  \
# 0    Ladies and gentlemen, please can you welcome ...  Romesh Ranganathan
# 1     strong language and adult humour. Ladies and...     Josh Widdicombe
# 2    When I think of Michael, I think of... Shakin...    Michael McIntyre
# 3    Ladies and gentlemen, girls and boys of Londo...        Miranda Hart
# 4     some strong language Ladies and gentlemen, t...         Dawn French
# 5     strong language -ANNOUNCER:-Ladies and gentl...       Dara O Briain
# 6    This programme contains strong language. Ladi...       Kevin Bridges
# 7     some strong language CHATTER We were all sli...       Bob Monkhouse
# 8    APPLAUSE Hello. Well, here we are, then. We m...       Victoria Wood
# 9     strong language OK, so I'm just going to pul...        Andy Parsons
# 10   Whoa, whoa! I can't have that. I can't have t...           Peter Kay
# 11   This programme contains strong language. WHIS...    Michael McIntyre
# ...

# %%
full_df = pd.concat([scraps_df, apollo_df, live_bbc_df, bbc_scripts_df]).reset_index(drop=True)

# %%
full_df['artist'] = full_df['artist'].str.strip()

# %%
full_df.sort_values('artist', inplace=True)

# %%
full_df = full_df.reset_index(drop=True)

# %%
print(full_df['full_transcript'].iloc[457])
# Out:
# (THUNDERCLAP) SPOOKY VOICE: Long ago, in a castle laboratory, (ELECTRICITY BUZZING) sort of like Frankenstein’s, you know, science turned abomination, a mad doctor’s dream to create a human being from the body parts of other human beings. A bit pointless, really. He wanted to create the world’s finest comedian. Popular, clever, funny. So a male comedian, obviously. Got a penis and everything. A little bit smaller than he would have wanted. But, you know, it’s fine. It’s average. He’s a little bit fat, but fat is funny. Average penis. Little bit chunky, but… So, please welcome to the stage… (BABA O’RILEY PLAYING) …creator of The Office, Extras, Flanimals, record-breaking stand-up, winner of three Golden Globes, two Primetime Emmys, and seven BAFTAs, a man with an average-sized penis – it’s fine, honestly – the one, the only, Mr Ricky Gervais. (CROWD CHEERING) (BABA O’RILEY CONTINUING)
#
# ...

# %%
full_df['artist'].iloc[116:119] = 'Dara Ó Briain'
# Out:
# /tmp/ipykernel_10190/85885370.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['artist'].iloc[116:119] = 'Dara Ó Briain'

# %%
full_df['artist'].iloc[139] = 'Dave Chappelle'
# Out:
# /tmp/ipykernel_10190/453499420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['artist'].iloc[139] = 'Dave Chappelle'

# %%
full_df['artist'].iloc[302] = 'Jon Richardson'
# Out:
# /tmp/ipykernel_10190/3934680898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['artist'].iloc[302] = 'Jon Richardson'

# %%
full_df
# Out:
#                                        full_transcript  \
# 0    [rock music playing]\n\n[indistinct chatter]\n...
# 1      strong language. CHEERING Yes, yes, yes! How...
# 2     Ladies and gentlemen, please welcome your hos...
# 3      some strong language and adult humour Ladies...
# 4    Adam Hills? CHEERING Hello, Apollo. I am going...
# 5    [man] Okay, ready, and… Take your own cue, Ada...
# 6    A NETFLIX COMEDY SPECIAL\nRecorded at the Casi...
# 7    Aisling Bea! APPLAUSE AND CHEERING Hello! Hell...
# 8    [dog barks] [FisherGreen’s Sisters Brothers pl...
# 9     Ladies and gentlemen, please welcome your hos...
# 10    Ladies and gentlemen, please welcome your hos...
# 11   Al Porter. CHEERING AND APPLAUSE Hello. Are yo...
# 12     some strong language Ladies and gentlemen, p...
# 13    'Ladies and gentlemen, 'please welcome your h...
# 14   Alex Edelman. Thank you so much for having me....
# 15   Ladies and gentlemen, please welcome to the st...
# ...

# %%
full_df = full_df.drop([59, 169, 324, 327, 336, 342, 345, 382, 413, 414, 455, 551]).reset_index(drop=True)

# %%
full_df.to_json('../raw_data/combined_scraps_bbc_df.json')
